# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=False)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/exp3"
# !ls
# Out:
# /content/drive/My Drive/exp3
# mainnotebook.ipynb

# %%
import requests
file_url = "https://cloud.tsinghua.edu.cn/f/52804d610c5a4547ba1e/?dl=1"
r = requests.get(file_url, stream=True)
with open("../exp3dataset/dataset.zip", "wb") as dataset:
    for chunk in r.iter_content(chunk_size=1024):
        if chunk:
            dataset.write(chunk)

# %%
# !pip install -U albumentations
# Out:
# Requirement already up-to-date: albumentations in /usr/local/lib/python3.6/dist-packages (0.4.3)
# ...

# %%
# !python train.py --network efficientdet-d4 --batch_size 16 --num_epoch 50
# Out:
# Loaded pretrained weights for efficientnet-b4
# 0 epoch: 	 start training....
# 100 iteration: training ...
#     epoch          : 0
#     iteration      : 100
#     cls_loss       : 0.5216476321220398
#     reg_loss       : 0.7154355049133301
#     mean_loss      : 1.4953531897068024
#     time           : 188.44312620162964
#     loss           : 1.266077292726395
# 1 epoch: 	 start training....
# 200 iteration: training ...
#     epoch          : 1
#     iteration      : 200
#     cls_loss       : 0.3311055898666382
#     reg_loss       : 0.5572131872177124
#     mean_loss      : 0.8440330276886622
# 300 iteration: training ...
#     epoch          : 1
#     iteration      : 300
#     cls_loss       : 0.31572219729423523
#     reg_loss       : 0.4321005940437317
#     mean_loss      : 0.7421330628650529
#     time           : 175.59913110733032
#     loss           : 0.6954439005002062
# 2 epoch: 	 start training....
# 400 iteration: training ...
#     epoch          : 2
# ...

# %%
# !python eval.py --dataset_root ./datasets --network efficientdet_d4 --weights ./weights/checkpoint_efficientdet-d4_78.pth
# Out:
# Loading checkpoint: ./weights/checkpoint_efficientdet-d4_78.pth ...
# Loaded pretrained weights for efficientnet-b4
# n_gpu_use:  1
# 100% 25/25 [00:03<00:00,  8.20it/s]
# 	 Start caculator mAP ...
# 	mAP:
# __background__: 0
# cat: 1.0
# painting: 1.0
# files: 0
# baby: 0
# gas tank: 0
# total mAP: 0.3333333333333333

# %%
from detect import Detect
detobj = Detect(weights='./weights/checkpoint_efficientdet-d4_89.pth',iou_threshold=0.3,network='efficientdet-d4')
f=open('./datasets/Configs/val.txt')
for line in f:
  print(detobj.detect(file_name='./datasets/Images/%s.jpg' % line.strip()))
# Out:
# Load pretrained Model
# Loaded pretrained weights for efficientnet-b4
# (['cat'], [[63, 280, 360, 548]], [100])
# (['cat'], [[306, 11, 672, 372]], [100])
# (['painting'], [[360, 187, 608, 498]], [100])
# (['painting'], [[280, 221, 452, 441]], [100])
# (['painting'], [[324, 60, 541, 359]], [100])
# (['cat'], [[159, 283, 392, 509]], [100])
# (['cat'], [[380, 135, 602, 344]], [100])
# (['baby'], [[377, 129, 588, 381]], [100])
# (['baby'], [[403, 122, 564, 293]], [100])
# (['baby'], [[224, 266, 360, 415]], [100])
# (['gas tank'], [[398, 3, 789, 674]], [100])
# (['gas tank'], [[399, 7, 740, 602]], [100])
# (['gas tank'], [[352, 3, 691, 577]], [100])
# (['gas tank'], [[381, 0, 780, 634]], [100])
# (['gas tank'], [[478, 51, 871, 707]], [100])
# (['files'], [[218, 169, 401, 390]], [100])
# (['files'], [[335, 24, 585, 304]], [100])
# (['painting'], [[606, 186, 796, 431]], [99])
# (['painting'], [[342, 37, 608, 387]], [100])
# (['painting'], [[250, 271, 474, 585]], [100])
# ...

# %%
# %debug
# Out:
# > /usr/local/lib/python3.6/dist-packages/albumentations/core/transforms_interface.py(142)update_params()
#     140         if hasattr(self, "fill_value"):
#     141             params["fill_value"] = self.fill_value
# --> 142         params.update({"cols": kwargs["image"].shape[1], "rows": kwargs["image"].shape[0]})
#     143         return params
#     144
#
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# ipdb> ·
# *** SyntaxError: invalid character in identifier
# ipdb> q

# %%
# !python detect.py --data data/ball.data --cfg cfg/yolov3.cfg --weights weights/best.pt
# Out:
# Namespace(cfg='cfg/yolov3.cfg', conf_thres=0.3, data='data/ball.data', fourcc='mp4v', half=False, images='data/samples', img_size=416, nms_thres=0.5, output='output', webcam=False, weights='weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# image 1/5 data/samples/basket&balloon.jpg: Done. (0.299s)
# image 2/5 data/samples/bus.jpg: Done. (0.076s)
# image 3/5 data/samples/football.jpg: Done. (0.091s)
# image 4/5 data/samples/three_balls.jpg: 416x416 1 basketballs, 3 volleyballs, 1 balloons, Done. (0.121s)
# image 5/5 data/samples/zidane.jpg: 256x416 2 basketballs, Done. (0.071s)
# Results saved to /content/drive/My Drive/YOLO_V3/output
# Done. (4.123s)

# %%
# !python test.py --data data/ball.data --cfg cfg/yolov3.cfg --weights weights/best.pt
# Out:
# Namespace(batch_size=16, cfg='cfg/yolov3.cfg', conf_thres=0.001, data='data/ball.data', img_size=416, iou_thres=0.5, nms_thres=0.5, save_json=False, weights='weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
#                          Class    Images   Targets         P         R       mAP        F1: 100% 3/3 [00:15<00:00,  6.44s/it]
#                            all        34        36   0.00991     0.853     0.575    0.0195
#                     basketball        34        13    0.0145         1     0.891    0.0287
#                       football        34         9     0.003     0.556   0.00912   0.00597
#                     volleyball        34         7   0.00613         1     0.651    0.0122
#                        balloon        34         7     0.016     0.857      0.75    0.0313

# %%
# !python -c "from utils import utils; utils.plot_results()"

# %%
# Out:
# UsageError: Line magic function `%vim` not found.
